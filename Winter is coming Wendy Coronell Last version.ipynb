# %% [markdown]
# # Winter is coming

# %% [markdown]
# This is a game based on chapter 9 of season 6 of Game of Thrones. "The battle of the bastards".
#
# By Wendy Coronell

# %%
### formating the game
print('*' * 120)
print("                                            Welcome to the battle!")
print('*' * 120)

#introduction to the game
print("You are Jon Snow and you serve the Night's Watch on the Wall. Your sister Sansa sought refuge on the Wall and tells you that in Winterfell your brother Rickon is a prisoner of Ramsay Bolton, she tells you how terrible Ramsay is and the harm he has done to her, she asks you to help her rescue Rickon.", 
      "\nYou send a raven to Winterfell and decide to meet Ramsay Bolton.")
print(input(prompt = "\n<Press enter to continue>"))
print("""Ramsay: Thank you for returning Lady Bolton safely. Now, dismount and kneel before me, surrender your army and proclaim me the true Lord of Winterfell and Warden of the North. I will pardon you for deserting the Night’s Watch. I will pardon these treasonous lords for betraying my house. Come, bastard, you don’t have the men, you don’t have the horses, and you don’t have Winterfell. Why lead those poor souls into slaughter? There’s no need for a battle. Get off your horse and kneel. I’m a man of mercy.""")
print(input(prompt = "\n<Press enter to continue>"))
#First stage

#defining the first step
print("Jon Snow has decided to declare war. Now you need to be prepared to defeat Ramsay. Remember that he likes to control other minds, be careful and don't fall into his threats.")

#definig your army
print("\nThis is your army:")        
army= [['Wildlings',500],['Giants',3],['Sir Davos soldiers',50],['The Red Witch',1],['Horses',50]]
for element, size in army:
      print(element +' : ', size)
print(input(prompt = "\n<Press enter to continue>"))
print('*' * 120)


#First stage
#defining enemy size

#while loop  for repeat an attempt if the user press a wrong number
enemy_attempts= 1
while enemy_attempts > 0:
    know_enemy=input(prompt = """Do you want to know your enemy size?:
                         Press 1 for Yes.
                         Press 2 for No.
                                        """)
    if know_enemy =='1' or know_enemy.lower() == 'yes':
        #defining enemies
        def enemy(*arg):
            print("\nThis is your enemy:")
    
            for item in arg:
                print(item)

        enemy('Soldiers: 1000', 'Horses: 500',
              'Archers: 300', 'Hungry dogs: 7')
        break
    elif know_enemy == '2' or know_enemy.lower() == 'no':
        print("\nI see you are not afraid of anything, like a true Northerner!")
        break
    else:
        print("\nPlease enter a valid option. Write the number 1 or 2.")
        
#formating
print('*' * 120)

#Second stage of the game
# importing random
import random
# generating a random scenario
scenario = random.randint(1,3)
#Only three attempst in case to write the wrong answer
strategy_attempts = 3

#conditioning first scenario
if scenario == 1:
    #Exiting the loop after three attempts
    while strategy_attempts > 0:
        strategy = input(prompt = """Now it is early in the morning, and you stand with your army, ready for battle. You need to choose your next move:
                     \n1. Go back to the Wall and wait there.
                     \n2. Go into battle knowing that you have a smaller army but are better in battle.
                     \n3. Run away and let him win.\n""").casefold()
        #conditional for the decision 1 played
        if strategy in ['go back', 'wall', 'came back', 'one','wait'] or strategy== '1'  in strategy:
            print("\nYou chose: Go back to the Wall and wait there.")
            input(prompt = '< Press enter to continue. >\n')
            #defining a second stage to continue the next step
            def second_stage():
                print("As you make your way back to the Wall, you encounter an army of White Walkers.")
                attempts = 2
                while attempts >0:
                    strategy_2 = input(prompt = """What do you decide to do?:
                               \n1. You decide to join the army of White Walkers.
                               \n2. You return again to fight with Ramsay.\n""").casefold()
                    if strategy_2 in ['white walkers', 'join', 'one'] or strategy_2 == '1'  in strategy_2:
                        def game_over3():
                            print("""\nJoining the White Walkers is not the best option.\nGame over!.""")
                        game_over3()
                        break
                    elif strategy_2 in['return','Ramsay','two'] or strategy_2 == '2' in strategy_2:
                        def game_over4():
                            print("""\nThe White Walkers blocked your way back and everyone died.\nGame over!.""")
                        game_over4()
                        break
                    else:
                        attempts-=1
                            
                        print(f"""\nThat is not a correct answer, remember to use only numbers 1 to 2. You have {attempts} attempt(s) remaining.\n""")
            
                print("\nYou ran out of attempts. Game over!")
            second_stage()
            break
        #elif clause for the decision played 2
        elif strategy in ['go into battle', 'two', 'better'] or strategy == '2' in strategy:
            print("\nYou chose: Go into battle knowing that you have a smaller army but are better in battle.")
            input(prompt = '< Press enter to continue. >\n')
            #Third stage of the game
            def thrid_stage():
                print("This battle is yours; remember that, for some reason, the God of Light brought Jon Snow back!.")
                attempts_2 = 2
                while attempts_2 > 0:
                    strategy_3 = input(prompt = """Now that the battle is about to start, Ramsay releases your brother Rickon, who starts running towards your army. You must decide how to rescue him:
                               \n1. You order your army to shoot arrows while you go looking for your brother.
                               \n2. You attack from the rear, making an unexpected move for the opposing army while searching for your brother.\n""").casefold()
                    #nested conditional for the following step
                    if strategy_3 in['one','shoot arrows','looking for your brother'] or strategy_3 == '1' in strategy_3:
                        def game_over2():
                            print("""\nRickon was not very fast, and he was hit by an arrow before the rescue.\nGame over!.""")
                        game_over2()
                        break
                    #Right decision
                    elif strategy_3 in['attack','rear','unexpected', 'searching','two'] or strategy_3 == '2'in strategy_3:
                        print("\nYou outsmarted Ramsay and didn't fall into his trap. You are one step closer to conquering Winterfell.")
                        input(prompt = '< Press enter to continue. >\n')
                        #Fourt stage of the game
                        def four_stage():
                            print("It is time to continue attacking the enemy; continue your strategy.")
                            attempts_3 = 2
                            while attempts_3 > 0:
                                strategy_4= input(prompt = """Decide the next move:
                                      \n1. Use the archers to attack the front, leave the giants in the rear, and bring the Littlefinger army to defeat the enemy.
                                      \n2. You divide your army, half on the battlefield and the other half you send to conquer the castle.\n""").casefold()
                                if strategy_4 in['archers','one','attack the front', 'giants','little finger'] or strategy_4 == '1'in strategy_4:
                                    #defining win function
                                    def win():
                                        print("Congratulations!!! you just won the battle. Winterfell is yours. Now you can make Ramsay pay for all the bad things he did.")
                                    win()
                                    break
                                elif strategy_4 in['divide','two','battlefield','half','castle'] or strategy_4 == '2' in strategy_4:
                                    def game_over1():
                                        print("""Ramsay has just destroyed your army and is on his way back to Winterfell. Splitting the army is not the best option; remember, you don't have many soldiers.\nGame over!.""")
                                    game_over1()
                                    break
                                else:
                                    attempts_3 -= 1
                                    print(f"""\nThat is not a correct answer, remember to use only numbers 1 to 2. You have {attempts_3} attempt(s) remaining.\n""")
                        four_stage()
                        break
                    else:
                        attempts_2-=1
                        print(f"""\nThat is not a correct answer, remember to use only numbers 1 to 2. You have {attempts_2} attempt(s) remaining.\n""")
            thrid_stage()
            break
        elif strategy in['three','let him win'] or strategy == '3' in strategy:
            strategy_attempts -= 1
            print("\nYou chose: Run away and let him win.")
            input(prompt = '< Press enter to continue. >\n')
            #defining fail function
            def game_over():
                print("""\n Game over! Running away does not represent Northerners. You don't deserve Winterfell.""")
            game_over()
            break
        else:
            strategy_attempts -= 1
            print(f"""\nThat is not a correct answer, remember to use only numbers 1 to 3. You have {strategy_attempts} attempt(s) remaining.\n""")
            
# Second scenario         
elif scenario == 2:
    second_attempts = 2
    # Exiting the loop after three attempts
    while second_attempts > 0:
        try:
            strategy_scenario_2 = input(prompt="""Imagine it is afternoon and your army tells you they are ready to attack. What decision do you make?:
                     \n1. Wait until nighttime because in the dark you can have a better head start.
                     \n2. Start the battle because your army is rested and ready to fight.
                     \n3. Wait for the enemy to appear and attack.\n""").casefold() 
            # Conditional for the decision 1 played
            if strategy_scenario_2 in ['wait', 'nighttime', 'dark', 'better'] or '1' in strategy_scenario_2:
                print("\nYou chose: Wait until nighttime because in the dark you can have a better head start.")
                input(prompt='< Press enter to continue. >\n')
                # Defining a second stage in the second scenario 
                def second_second_stage():
                    print("While you decided to wait, Ramsay sent small groups to attack your camp and weaken your army.")
                    second2_attempts = 2
                    while second2_attempts >0:
                        strategy2_scenario_2 = input(prompt="""What do you decide to do?:
                               \n1. You send the giants to defeat the groups that came to your camp.
                               \n2. You blow the trumpets and alert your army, and they begin to attack.\n""").casefold()
                        if strategy2_scenario_2 in ['giants', 'defeat', 'camp'] or '1' in strategy2_scenario_2:
                            def game_over1_second():
                                print("""\nThe giants were slower than the soldiers Ramsay sent and were defeated. Now your camp is in flames.\nGame over!.""")
                            game_over1_second()
                            break
                        elif strategy2_scenario_2 in ['blow', 'trumpets', 'alert', 'attack'] or '2' in strategy2_scenario_2:
                            def game_over2_second():
                                print("While your army was getting ready, Ramsay sent arrows to your camp. Most of your army died. Game over!")
                            game_over2_second()
                            break
                        else:
                            second2_attempts -= 1
                            print(f"""\nThat is not a correct answer, remember to use only numbers 1 to 2. You have {second2_attempts} attempt(s) remaining.\n""")
                second_second_stage()
                break
            # Conditional for the decision 2 played
            elif strategy_scenario_2 in ['start', 'rested', 'ready', 'fight'] or '2' in strategy_scenario_2:
                print("\nYou chose: Start the battle because your army is rested and ready to fight.")
                input(prompt='< Press enter to continue. >\n')
                # Defining a third stage in the second scenario 
                def third_stage_second():
                    print("Good choice! Your army is rested and energized to face what is to come:")
                    second3_attempts = 2
                    while second3_attempts> 0:
                        strategy3_scenario_2 = input(prompt="""Now that the battle is about to start, decide your next movement:
                               \n1. Fake a retreat to split the enemy forces. Once the enemy is dispersed, attack the separated units with your full force.
                               \n2. Launch a series of small, quick attacks to weaken enemy morale and create fear and uncertainty.\n""").casefold()
                        # Nested conditional for the following step
                        if strategy3_scenario_2 in ['fake', 'retreat', 'split the enemy'] or '1' in strategy3_scenario_2:
                            def game_over3_second():
                                print("""You fell into Ramsay's trap. He had small groups strategically placed to attack. Your army was surprised!. Game Over!""")
                            game_over3_second()
                            break
                        elif strategy3_scenario_2 in ['launch', 'quick attacks', 'create fear'] or '2' in strategy3_scenario_2:
                            print("\nYou outsmarted Ramsay and didn't fall into his trap. You are one step closer to conquering Winterfell.")
                            input(prompt='< Press enter to continue. >\n')
                            # Fourth stage of the game
                            def four_stage_second():
                                print("Continue the battle and finish it Northern style.")
                                second4_attempts = 2
                                while second4_attempts> 0:
                                    strategy4_scenario_2 = input(prompt="""You created confusion in your enemy, and the night has come. Now it is time to use the darkness to your advantage. Continue the strategy:
                                    \n1. Launch flaming arrows and use the wildlings to attack the front, and Ser Davos' knights to attack the defense of Winterfell.
                                    \n2. Use the wolves to surprise the retreating army and send the three giants to the forefront of the battle.\n""").casefold()
                                    # Nested conditional for the following step
                                    if strategy4_scenario_2 in ['launch', 'flaming arrows', 'wildlings', 'ser. davos', 'knights'] or '1' in strategy4_scenario_2:
                                        print("Arrows killed more than half of Ramsay's army and flames lit up the Battalan terrain, taking the enemy by surprise.")
                                        def win_second():
                                            print("Ramsay's army surrenders, your brother Rickon is alive and you can go to Winterfell to rescue him. Congratulations, you won the battle!")
                                        win_second()
                                        break
                                    elif strategy4_scenario_2 in ['wolves', 'surprise', 'giants', 'retreating', 'forefront'] or '2' in strategy4_scenario_2:
                                        print("The wolves were not enough to defeat the army, and the giants were attacked with spears.")
                                        def game_over4_second():
                                            print("Ramsay's army returns to the battlefield and destroys your entire army. Game over!")
                                        game_over4_second()
                                        break
                                    else:
                                        second4_attempts-=1
                                        print(f"""\nThat is not a correct answer, remember to use only numbers 1 to 2. You have {second4_attempts} attempt(s) remaining.\n""")
                                        
                            four_stage_second()
                            break
                        else:
                            second3_attempts -= 1
                            print(f"""\nThat is not a correct answer, remember to use only numbers 1 to 2. You have {second3_attempts} attempt(s) remaining.\n""")
                third_stage_second()
                break
            elif strategy_scenario_2 in ['wait for enemy', 'attack', 'appear'] or '3' in strategy_scenario_2:
                print("\nYou chose: Wait for the enemy to appear and attack.")
                input(prompt='< Press enter to continue. >\n')
                def game_over5_second():
                    print("Waiting for the enemy to arrive does not seem like a good idea. Ramsay attacked your army unexpectedly. Game over!.")
                game_over5_second()
                break
            else:
                second_attempts -= 1
                print(f"""\nThat is not a correct answer, remember to use only numbers 1 to 2. You have {second_attempts} attempt(s) remaining.\n""")
        
        except NameError:
            print("Please write the correct number")

            
# Third scenario
elif scenario==3:
    strategy_attempts3 =3
    #Exiting the loop after three attempts
    while strategy_attempts3 > 0:
        try:
            strategy_scenario_3 = input(prompt = """It is night, and the Red Witch comes to you, telling you that the Lord of Light wants you to start the battle at night. What decision do you make?:
                     \n1. The Lord of Light brought you back; you decide to start the battle at night.
                     \n2. You better wait for sunrise and prepare your army for a surprise attack.
                     \n3. The cold of the night does not allow you to advance; you prefer to wait until the next day.\n""").casefold()  
            #conditional for the decision 1 played
            if strategy_scenario_3 in ['lord of light', 'start the battle', 'night'] or strategy_scenario_3== '1'  in strategy_scenario_3:
                print("You are brave, and your army noticed!. Well done!.")
                #nested conditional for wining
                def second_third_stage():
                    print("While the night progresses, a raven arrives from Ramsay, saying that if you attack at night, your brother dies.")
                    attempts1_3 = 2
                    while attempts1_3 > 0:
                        strategy2_scenario_3 = input(prompt = """What do you decide to do?:
                        \n1. You cancel the attack order and wait for a better moment.
                        \n2. Take advantage of the darkness of the night and make an ambush, divide your army to attack the city from the inside, and place your army strategically outside.\n""").casefold()
                        if strategy2_scenario_3 in ['cancel', 'wait','better moment'] or strategy2_scenario_3 =='1' in strategy2_scenario_3:
                            print("You fell into the trap")
                            def game_over1_third():
                                print("Ramsay organized a surprise attack, and every army has been defeated. Game over!")
                            game_over1_third()
                            break
                        elif strategy2_scenario_3 in ['take', 'advantage','ambush','divide','inside','outside'] or strategy2_scenario_3 =='2' in strategy2_scenario_3:
                            print("Good choice! Ramsay thought you wouldn't attack, so while he was preparing his army to attack you, you arrived first, taking advantage.")
                            def win_third():
                                print("The ambush was effective. Now the gates of Winterfell are open; you can take the city. Congratulations!.")
                            win_third()
                            break
                        else:
                            attempts1_3 -=1
                            print(f"""\nThat is not a correct answer, remember to use only numbers 1 to 2. You have {attempts1_3} attempt(s) remaining.\n""")
                second_third_stage()
            elif strategy_scenario_3 in ['wait', 'sunrise', 'prepare', 'surprise attack'] or strategy_scenario_3== '2'  in strategy_scenario_3:
                print("While waiting for the sunrise, you were ambushed by your enemy!.")
                def third_third_stage():
                    print("it's time to solve it!.")
                    attempts2_3 = 2
                    while attempts2_3 >0:
                        strategy3_scenario_3 =input (prompt= """What do you decide to do?:
                        \n1. You quickly organize your army and they run away to the Wall.
                        \n2. Fight the battle in your camp and send a small army to attack the city.""")
                        if strategy3_scenario_3 in ['quickly','run away', 'wall'] or strategy3_scenario_3 =='1' in strategy3_scenario_3 :
                            print("In the escape to the Wall, you meet an army of White Walkers.")
                            def game_over2_third():
                                print("Your army has been defeated by the White Walkers. Game over!")
                            game_over2_third()
                            break
                        elif strategy3_scenario_3 in ['fight','camp','small','army','attack the city'] or strategy3_scenario_3 =='2' in strategy3_scenario_3:
                            print("Your army was not dressed and ready for battle; many died in the ambush.")
                            def game_over3_third():
                                print("Your army has been defeated, and you have been taken captive to Ramsay's dog kennel. Game over!")
                            game_over3_third()
                            break
                        else:
                            attempts2_3 -=1
                            print(f"""\nThat is not a correct answer, remember to use only numbers 1 to 2. You have {attempts2_3} attempt(s) remaining.\n""")
                third_third_stage()
            elif strategy_scenario_3 in ['cold', 'next', 'day'] or strategy_scenario_3== '3'  in strategy_scenario_3:
                print("Remember that winter is coming; you must be prepared.")
                def game_over4_third():
                    print("True Northerners are not afraid of the cold of the night. Game over!")
                game_over4_third()
                break
            else:
                strategy_attempts3 -=1
                print(f"""\nThat is not a correct answer, remember to use only numbers 1 to 2. You have {strategy_attempts3} attempt(s) remaining.\n""")
            break
        except  TypeError:
            print("An error has occurred, please try again.")
else:
    print(f"""\nThat is not a correct answer, remember to use only numbers 1 to 3.""")

print('*' * 120)
# Out:
# ************************************************************************************************************************
#                                             Welcome to the battle!
# ************************************************************************************************************************
# You are Jon Snow and you serve the Night's Watch on the Wall. Your sister Sansa sought refuge on the Wall and tells you that in Winterfell your brother Rickon is a prisoner of Ramsay Bolton, she tells you how terrible Ramsay is and the harm he has done to her, she asks you to help her rescue Rickon.
# You send a raven to Winterfell and decide to meet Ramsay Bolton.
#
# <Press enter to continue>
#
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Benioff, D., & Weiss, D. B. (2015). Battle of the Bastards.
